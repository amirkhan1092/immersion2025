# %%
class TreeNode:
    def __init__(self, value=0, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

def build_tree(values):
    if not values:
        return None

    def build_tree_helper(index):
        if index >= len(values) or values[index] == 'false':
            return None, index

        node = TreeNode(int(values[index]))
        index += 1

        if index < len(values) and values[index] == 'true':
            node.left, index = build_tree_helper(index + 1)
        else:
            index += 1

        if index < len(values) and values[index] == 'true':
            node.right, index = build_tree_helper(index + 1)
        else:
            index += 1

        return node, index

    root, _ = build_tree_helper(0)
    return root

def invert_tree(root):
    if root:
        root.left, root.right = invert_tree(root.right), invert_tree(root.left)
    return root

def pre_order_traversal(root):
    if not root:
        return []
    result = [root.value]
    if root.left:
        result += pre_order_traversal(root.left)
    if root.right:
        result += pre_order_traversal(root.right)
    return result

def print_pre_order(root):
    if not root:
        return []
    result = []
    stack = [root]
    while stack:
        node = stack.pop()
        result.append(str(node.value))
        if node.right:
            stack.append(node.right)
        if node.left:
            stack.append(node.left)
    return " ".join(result)

if 1:

    values = "4 true 2 true 1 false false true 3 false false true 7 true 6 false false true 9 false false".split()
    
    root = build_tree(values)
    inverted_root = invert_tree(root)
    pre_order_result = pre_order_traversal(inverted_root)
    
    result = []
    for val in pre_order_result:
        result.append(str(val))
        if inverted_root:
            result.append("true")
        else:
            result.append("false")

    print(" ".join(result))
# Out:
# 4 true 7 true 9 true 6 true 2 true 3 true 1 true

# %%
class TreeNode:
    def __init__(self, value=0, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

def build_tree(values):
    if not values:
        return None

    def build_tree_helper(index):
        if index >= len(values) or values[index] == 'false':
            return None, index

        node = TreeNode(int(values[index]))
        index += 1

        if index < len(values) and values[index] == 'true':
            node.left, index = build_tree_helper(index + 1)
        else:
            index += 1

        if index < len(values) and values[index] == 'true':
            node.right, index = build_tree_helper(index + 1)
        else:
            index += 1

        return node, index

    root, _ = build_tree_helper(0)
    return root

def invert_tree(root):
    if root:
        root.left, root.right = invert_tree(root.right), invert_tree(root.left)
    return root

def serialize_tree(root):
    result = []
    def serialize(node):
        if not node:
            result.append('false')
            return
        result.append(str(node.value))
        if node.left or node.right:  # If there's any child
            result.append('true')
            serialize(node.left)
            serialize(node.right)
        else:
            result.append('false')
            result.append('false')
    serialize(root)
    return " ".join(result)

if 1:

    values = " 8 true 6 true 5 true 3 false false true 7 false false true 10 false false".split()
    
    root = build_tree(values)
    inverted_root = invert_tree(root)
    serialized_result = serialize_tree(inverted_root)
    
    print(serialized_result)
# Out:
# 8 true false 6 true 10 false false 5 true 7 false false 3 false false

# %%
class TreeNode:
    def __init__(self, value=0, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

def build_tree(values):
    def build_tree_helper(index):
        if index >= len(values):
            return None, index
        
        value = values[index]
        if value == "false":
            return None, index + 1
        
        node = TreeNode(int(value))
        if index + 1 < len(values):
            node.left, index = build_tree_helper(index + 1)
        if index + 1 < len(values):
            node.right, index = build_tree_helper(index + 1)
        
        return node, index + 1

    root, _ = build_tree_helper(0)
    return root

def invert_tree(root):
    if root:
        root.left, root.right = invert_tree(root.right), invert_tree(root.left)
    return root

def serialize_tree(root):
    result = []
    def serialize(node):
        if not node:
            result.append("false")
        else:
            result.append(str(node.value))
            serialize(node.left)
            serialize(node.right)
    serialize(root)
    return " ".join(result)

if 1:
    import sys
    input = sys.stdin.read().strip()
    values = "4 true 2 true 1 false false true 3 false false true 7 true 6 false false true 9 false false".split()
    
    root = build_tree(values)
    inverted_root = invert_tree(root)
    serialized_result = serialize_tree(inverted_root)
    
    print(serialized_result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 49
#      46 input = sys.stdin.read().strip()
#      47 values = "4 true 2 true 1 false false true 3 false false true 7 true 6 false false true 9 false false".split()
# ---> 49 root = build_tree(values)
#      50 inverted_root = invert_tree(root)
#      51 serialized_result = serialize_tree(inverted_root)
#
# Cell In[10], line 24, in build_tree(values)
#      20         node.right, index = build_tree_helper(index + 1)
#      22     return node, index + 1
# ---> 24 root, _ = build_tree_helper(0)
#      25 return root
#
# Cell In[10], line 18, in build_tree.<locals>.build_tree_helper(index)
#      16 node = TreeNode(int(value))
#      17 if index + 1 < len(values):
# ---> 18     node.left, index = build_tree_helper(index + 1)
#      19 if index + 1 < len(values):
#      20     node.right, index = build_tree_helper(index + 1)
#
# Cell In[10], line 16, in build_tree.<locals>.build_tree_helper(index)
#      13 if value == "false":
#      14     return None, index + 1
# ---> 16 node = TreeNode(int(value))
#      17 if index + 1 < len(values):
#      18     node.left, index = build_tree_helper(index + 1)
#
# ValueError: invalid literal for int() with base 10: 'true'
